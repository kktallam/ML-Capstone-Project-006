# %%
import os, time, requests, pandas as pd
from datetime import date, timedelta, datetime
from dateutil.relativedelta import relativedelta
import re, html
from typing import Iterable, Dict, List
import numpy as np
import ast

# %%
MAX_CHAR = 2000
WINDOW = 1

# %%
news = pd.read_csv('../data/guardian_financial_news_master.csv')
news['article_id'] = news.index
news
# Out:
#       version https://git-lfs.github.com/spec/v1  \
# 0                                 size 371154095
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 32981                                        NaN
# 32982                                        NaN
# 32983                                        NaN
# 32984                                        NaN
# 32985                                        NaN
#
#                                                      url  \
# 0                                                    NaN
# 1      https://www.theguardian.com/technology/2017/fe...
# 2      https://www.theguardian.com/politics/blog/live...
# 3      https://www.theguardian.com/business/live/2017...
# 4      https://www.theguardian.com/business/nils-prat...
# ...                                                  ...
# 32981  https://www.theguardian.com/world/2022/dec/02/...
# 32982  https://www.theguardian.com/business/2022/dec/...
# 32983  https://www.theguardian.com/business/2022/dec/...
# 32984  https://www.theguardian.com/politics/2022/dec/...
# 32985  https://www.theguardian.com/politics/2022/dec/...
#
#                                                    title  \
# 0                                                    NaN
# 1      Facebook's Oculus must pay $500m in virtual re...
# 2      MPs vote to give May power to trigger article ...
# 3      Federal Reserve leaves interest rates on hold,...
# 4      TalkTalk hoping for rapid results as Dunstone ...
# ...                                                  ...
# 32981  EU states agree $60 a barrel cap on Russian oi...
# 32982  Supermarkets don’t create jobs, they destroy t...
# 32983  Insurers end war-risk cover for shipping in Uk...
# 32984  A treatment-based approach to tackling hard dr...
# 32985  Labour’s own shameful immigration record | Letter
#
#                    pub_date  \
# 0                       NaN
# 1      2017-02-01T22:36:43Z
# 2      2017-02-01T21:21:40Z
# 3      2017-02-01T21:07:12Z
# 4      2017-02-01T19:29:32Z
# ...                     ...
# 32981  2022-12-02T18:09:34Z
# 32982  2022-12-08T17:34:21Z
# 32983  2022-12-28T16:58:35Z
# 32984  2022-12-22T17:14:33Z
# 32985  2022-12-29T18:15:38Z
#
#                                                  summary  \
# 0                                                    NaN
# 1      Jury determined that VR company’s CEO Palmer L...
# 2      Rolling coverage of the day’s political develo...
# 3       US central bank resists raising interest rate...
# 4      Investors should welcome Sir Charles’s decisio...
# ...                                                  ...
# 32981  Poland, which was pushing for low cap, says de...
# 32982  Letter: <strong>Alistair Herbert </strong>says...
# 32983  Move comes as a result of reinsurers exiting t...
# 32984  Letters:<strong> Barry Coppinger </strong>writ...
# 32985  <strong>Letter: </strong>From Harold Wilson to...
#
#                                                     body  article_id
# 0                                                    NaN           0
# 1      The Facebook-owned company Oculus has been ord...           1
# 2      MPs have taken a historic step towards taking ...           2
# 3      And finally, Wall Street has closed a little h...           3
# 4      You can understand why Sir Charles Dunstone mi...           4
# ...                                                  ...         ...
# 32981  European Union member states have agreed to pu...       32981
# 32982  You report that Asda “is planning to open 300 ...       32982
# 32983  Ship insurers are cancelling war-risk coverage...       32983
# 32984  Simon Jenkins (Even England’s police want to d...       32984
# 32985  If Nigel Farage can mobilise voters around imm...       32985
#
# [32986 rows x 7 columns]

# %%
entities = pd.read_excel('../data/sp_500_constituents.xlsx')

TICKER_MAP = {}
for _, row in entities.iterrows():
    ticker = row['Ticker']
    name = row['Search Keywords']    
    TICKER_MAP[ticker] = [t.strip() for t in name.split(',') if t.strip()]

TICKER_MAP
# Out:
# {'ORCL': ['ORCL', 'Oracle', 'Oracle Corp'],
#  'MSFT': ['MSFT', 'Microsoft', 'Microsoft Corp'],
#  'TROW': ['T Rowe Price', 'T Rowe Price Group Inc', 'TROW', 'T Rowe'],
#  'HON': ['HON', 'Honeywell', 'Honeywell International Inc'],
#  'ADM': ['ADM',
#   'Archer Daniels Midland',
#   'Archer Daniels Midland Co',
#   'Archer Daniels'],
#  'FISV': ['FISV', 'Fiserv', 'Fiserv Inc'],
#  'KO': ['Coca Cola', 'Cocala', 'KO', 'Coke'],
#  'CDNS': ['CDNS',
#   'Cadence Design',
#   'Cadence Design Systems',
#   'Cadence Design Systems Inc'],
#  'ED': ['Consolidated Edison', 'Consolidated Edison Inc', 'ED'],
#  'XRAY': ['Dentsply Sirona', 'Dentsply Sirona Inc', 'XRAY'],
#  'FAST': ['FAST', 'Fastenal', 'Fastenal Co'],
#  'DTE': ['DTE Energy', 'DTE Energy Co', 'DTE'],
#  'ETN': ['ETN', 'Eaton', 'Eaton Corp', 'Eaton Corp Plc'],
#  'SIVB': ['SVB Financial',
#   'SVB Financial Group',
#   'SIVB',
#   'Silicon Valley Bank'],
#  'XOM': ['Exxon Mobil', 'Exxon Mobil Corp', 'XOM'],
#  'MGM': ['MGM Resorts', 'MGM Resorts International', 'MGM'],
#  'WM': ['WM', 'Waste Management Del', 'Waste Management Inc Del'],
#  'GD': ['GD', 'General Dynamics', 'General Dynamics Corp'],
#  'GE': ['GE', 'General Electric', 'General Electric Co'],
#  'LH': ['LH',
#   'Laboratory America',
#   'Laboratory Corp America',
#   'Laboratory Corp'],
#  'NXPI': ['NXP Semiconductors', 'NXPI'],
#  'CHTR': ['CHTR', 'Charter Communications', 'Charter Communications Inc New'],
#  'LYB': ['LYB', 'Lyondellbasell Industries', 'Lyondellbasell'],
#  'GM': ['GM', 'General Motors', 'General Motors Co'],
#  'TT': ['TT', 'Trane', 'Trane Technologies', 'Trane Technologies Plc'],
#  'FRC': ['FRC', 'First Republic Bank SF', 'First Republic Bank'],
#  'FLT': ['FLT',
#   'Fleetcor',
#   'Fleetcor Technologies',
#   'Fleetcor Technologies Inc'],
#  'TRGP': ['TRGP', 'Targa Resources', 'Targa Resources Corp', 'Targa'],
#  'IBM': ['Business Machs', 'IBM', 'International Business Machs Cor'],
#  'KMI': ['KMI', 'Kinder Morgan', 'Kinder Morgan Inc'],
#  'HCA': ['H C A Healthcare', 'H C A Healthcare Inc', 'HCA'],
#  'HII': ['HII', 'Huntington Ingalls', 'Huntington Ingalls Inds Inc'],
#  'MPC': ['MPC', 'Marathon Petroleum', 'Marathon Petroleum Corp'],
#  'XYL': ['XYL', 'Xylem', 'Xylem Inc'],
#  'APTV': ['APTV', 'Aptiv', 'Aptiv Plc'],
#  'EPAM': ['EPAM', 'Epam', 'Epam Systems', 'Epam Systems Inc'],
#  'ENPH': ['ENPH', 'Enphase Energy', 'Enphase Energy Inc', 'Enphase'],
#  'PSX': ['PSX', 'Phillips 66', 'Phillips'],
#  'META': ['Facebook', 'META', 'Meta', 'Meta Platforms', 'Meta Platforms Inc'],
#  'NOW': ['NOW', 'Servicenow', 'Servicenow Inc'],
#  'PNR': ['PNR', 'Pentair', 'Pentair Plc'],
#  'FANG': ['Diamondback Energy', 'Diamondback Energy Inc', 'FANG'],
#  'PCG': ['PG&E', 'PG&E Corp', 'PGAndE', 'PCG'],
#  'ABBV': ['ABBV', 'Abbvie', 'Abbvie Inc'],
#  'NCLH': ['NCLH', 'Norwegian Cruise Line', 'Norwegian Cruise Lines'],
#  'ZTS': ['ZTS', 'Zoetis', 'Zoetis Inc'],
#  'PEP': ['PEP', 'Pepsico', 'Pepsico Inc'],
#  'MO': ['Altria', 'Altria Group Inc', 'MO'],
#  'IQV': ['IQV', 'Iqvia', 'Iqvia Holdings Inc'],
#  'COP': ['COP', 'Conocophillips'],
#  'CDW': ['CDW', 'CDW Corp'],
#  'NWSA': ['NWSA'],
#  'NWS': ['NWS'],
#  'AMGN': ['AMGN', 'Amgen', 'Amgen Inc'],
#  'SLB': ['SLB', 'Schlumberger', 'Schlumberger Ltd'],
#  'ALLE': ['ALLE', 'Allegion', 'Allegion Plc'],
#  'HLT': ['HLT', 'Hilton Worldwide', 'Hilton Worldwide Holdings Inc', 'Hilton'],
#  'CVX': ['CVX', 'Chevron', 'Chevron Corp New'],
#  'GOOG': ['Alphabet', 'Alphabet Inc', 'GOOG', 'Google'],
#  'PAYC': ['PAYC', 'Paycom Software', 'Paycom Software Inc', 'Paycom'],
#  'AAPL': ['AAPL', 'Apple', 'Apple Inc'],
#  'AMAT': ['AMAT', 'Applied Materials', 'Applied Materials Inc'],
#  'ANET': ['ANET', 'Arista Networks', 'Arista Networks Inc'],
#  'CTLT': ['CTLT', 'Catalent', 'Catalent Inc'],
#  'SYF': ['SYF', 'Synchrony Financial'],
#  'CZR': ['CZR', 'Caesars Entertainment', 'Caesars Entertainment Inc'],
#  'CFG': ['CFG', 'Citizens Financial', 'Citizens Financial Group Inc'],
#  'KEYS': ['KEYS',
#   'Keysight',
#   'Keysight Technologies',
#   'Keysight Technologies Inc'],
#  'MRO': ['MRO', 'Marathon Oil', 'Marathon Oil Corp'],
#  'VMC': ['VMC', 'Vulcan Materials', 'Vulcan Materials Co'],
#  'SEDG': ['SEDG',
#   'Solaredge',
#   'Solaredge Technologies',
#   'Solaredge Technologies Inc'],
#  'ETSY': ['ETSY', 'Etsy', 'Etsy Inc'],
#  'KHC': ['KHC', 'Kraft Heinz', 'Kraft Heinz Co'],
#  'PYPL': ['PYPL', 'Paypal', 'Paypal Holdings Inc'],
#  'TXN': ['TXN', 'Texas Instruments', 'Texas Instruments Inc'],
#  'HPE': ['HPE', 'Hewlett Packard Enterprise', 'Hewlett Packard Enterprise Co'],
#  'EIX': ['EIX', 'Edison International'],
#  'MTCH': ['MTCH', 'Match Group'],
#  'FTV': ['FTV', 'Fortive', 'Fortive Corp'],
#  'LW': ['LW', 'Lamb Weston', 'Lamb Weston Holdings Inc'],
#  'INVH': ['INVH', 'Invitation Homes', 'Invitation Homes Inc'],
#  'HSY': ['HSY', 'Hershey', 'Hershey Co'],
#  'KR': ['KR', 'Kroger', 'Kroger Co'],
#  'IR': ['IR', 'Ingersoll Rand', 'Ingersoll Rand Inc'],
#  'DD': ['DD', 'Dupont De Nemours', 'Dupont De Nemours Inc'],
#  'CVS': ['CVS Health', 'CVS Health Corp', 'CVS'],
#  'GIS': ['GIS', 'General Mills', 'General Mills Inc'],
#  'VICI': ['VICI', 'Vici Properties', 'Vici Properties Inc'],
#  'SPGI': ['S&P Global', 'S&P Global Inc', 'S And P Global', 'SPGI'],
#  'CDAY': ['CDAY',
#   'Ceridian H C M',
#   'Ceridian H C M Holding',
#   'Ceridian H C M Holding Inc'],
#  'WRB': ['W.R. Berkley', 'W.R. Berkley Corp', 'WRB'],
#  'KMB': ['KMB', 'Kimberly Clark', 'Kimberly Clark Corp'],
#  'RTX': ['RTX',
#   'Raytheon',
#   'Raytheon Technologies',
#   'Raytheon Technologies Corp'],
#  'KDP': ['KDP', 'Keurig Dr Pepper', 'Keurig Dr Pepper Inc'],
#  'LIN': ['LIN', 'Linde', 'Linde Plc'],
#  'PG': ['P&G',
#   'PG',
#   'Procter & Gamble',
#   'Procter & Gamble Co',
#   'Procter And Gamble'],
#  'MRNA': ['MRNA', 'Moderna', 'Moderna Inc'],
#  'SO': ['SO', 'Southern', 'Southern Co'],
#  'FOXA': ['FOXA', 'Fox', 'Fox Corp'],
#  'FOX': ['FOX', 'Fox', 'Fox Corp'],
#  'DOW': ['DOW', 'Dow Inc'],
#  'CAT': ['CAT', 'Caterpillar', 'Caterpillar Inc'],
#  'CTVA': ['CTVA', 'Corteva', 'Corteva Inc'],
#  'AMCR': ['AMCR', 'Amcor', 'Amcor Plc'],
#  'CL': ['CL', 'Colgate Palmolive', 'Colgate Palmolive Co', 'Colgate'],
#  'FMC': ['FMC', 'FMC Corp', 'FMC'],
#  'CARR': ['CARR', 'Carrier Global', 'Carrier Global Corp'],
#  'OTIS': ['OTIS', 'Otis Worldwide', 'Otis Worldwide Corp'],
#  'DE': ['DE', 'Deere', 'Deere & Co'],
#  'BMY': ['BMY', 'Bristol Myers Squibb', 'Bristol Myers Squibb Co', 'Bristol'],
#  'WBA': ['WBA', 'Walgreens Boots Alliance', 'Walgreens Boots Alliance Inc'],
#  'BA': ['BA', 'Boeing', 'Boeing Co'],
#  'IVZ': ['IVZ', 'Invesco', 'Invesco Ltd'],
#  'VTRS': ['VTRS', 'Viatris', 'Viatris Inc'],
#  'ABT': ['ABT', 'Abbott Laboratories'],
#  'AAL': ['AAL', 'American Airlines', 'American Airlines Group Inc'],
#  'OGN': ['OGN', 'Organon', 'Organon & Co'],
#  'LMT': ['LMT', 'Lockheed Martin', 'Lockheed Martin Corp'],
#  'WRK': ['WRK', 'Westrock', 'Westrock Co'],
#  'NEM': ['NEM', 'Newmont', 'Newmont Corp'],
#  'CAH': ['CAH', 'Cardinal Health', 'Cardinal Health Inc'],
#  'IP': ['IP', 'International Paper', 'International Paper Co'],
#  'EXC': ['EXC', 'Exelon', 'Exelon Corp'],
#  'CNP': ['CNP', 'Centerpoint Energy', 'Centerpoint Energy Inc'],
#  'PFE': ['PFE', 'Pfizer', 'Pfizer Inc'],
#  'EMR': ['EMR', 'Emerson Electric', 'Emerson Electric Co'],
#  'JNJ': ['J&J', 'JNJ', 'Johnson & Johnson', 'Johnson And Johnson'],
#  'GLW': ['Corning', 'Corning Inc', 'GLW'],
#  'PPG': ['PPG Industries', 'PPG Industries Inc', 'PPG'],
#  'PPL': ['PPL Corp', 'PPL'],
#  'MMM': ['3M', '3M Co', 'MMM'],
#  'CEG': ['CEG', 'Constellation Energy', 'Constellation Energy Corp'],
#  'MRK': ['MRK', 'Merck & Co', 'Merck'],
#  'MSI': ['MSI', 'Motorola', 'Motorola Solutions'],
#  'WBD': ['WBD', 'Warner Bros', 'Warner Bros Discovery'],
#  'FE': ['FE', 'Firstenergy', 'Firstenergy Corp'],
#  'CMS': ['CMS Energy', 'CMS Energy Corp', 'CMS'],
#  'CHD': ['CHD', 'Church & Dwight', 'Church & Dwight Inc', 'Church And Dwight'],
#  'CINF': ['CINF', 'Cincinnati Financial', 'Cincinnati Financial Corp'],
#  'WEC': ['WEC Energy', 'WEC Energy Group', 'WEC'],
#  'TXT': ['TXT', 'Textron', 'Textron Inc'],
#  'CTAS': ['CTAS', 'Cintas', 'Cintas Corp'],
#  'PEG': ['PEG',
#   'Public Service Enterprise',
#   'Public Service Enterprise Gp Inc'],
#  'HAL': ['HAL', 'Halliburton', 'Halliburton Co'],
#  'XEL': ['XCEL Energy', 'XCEL Energy Inc', 'XEL'],
#  'ETR': ['ETR', 'Entergy', 'Entergy Corp New'],
#  'EVRG': ['EVRG', 'Evergy', 'Evergy Inc'],
#  'AEP': ['AEP', 'American Electric Power', 'American Electric Power Co Inc'],
#  'NEE': ['NEE', 'Nextera Energy', 'Nextera Energy Inc'],
#  'EQT': ['EQT', 'EQT Corp', 'EQT'],
#  'HWM': ['HWM', 'Howmet Aerospace', 'Howmet Aerospace Inc'],
#  'NOC': ['NOC', 'Northrop Grumman', 'Northrop Grumman Corp'],
#  'AEE': ['AEE', 'Ameren', 'Ameren Corp'],
#  'CMA': ['CMA', 'Comerica', 'Comerica Inc'],
#  'OKE': ['OKE', 'Oneok', 'Oneok Inc New'],
#  'CPB': ['CPB', 'Campbell Soup', 'Campbell Soup Co'],
#  'WHR': ['WHR', 'Whirlpool', 'Whirlpool Corp'],
#  'LHX': ['L3Harris',
#   'L3Harris Technologies',
#   'L3Harris Technologies Inc',
#   'LHX'],
#  'F': ['F', 'Ford Motor Co', 'Ford Motors', 'Ford'],
#  'DOV': ['DOV', 'Dover', 'Dover Corp'],
#  'DIS': ['DIS', 'Disney', 'Walt Disney'],
#  'L': ['L', 'Loews', 'Loews Corp'],
#  'K': ['K', 'Kellogg', 'Kellogg Co'],
#  'HPQ': ['HP', 'HP Inc', 'HPQ'],
#  'BAX': ['BAX', 'Baxter', 'Baxter International Inc'],
#  'DUK': ['DUK', 'Duke Energy', 'Duke Energy Corp New'],
#  'PNW': ['PNW', 'Pinnacle West Capital', 'Pinnacle West Capital Corp'],
#  'APD': ['APD',
#   'Air Products & Chemicals',
#   'Air Products & Chemicals Inc',
#   'Air Products And Chemicals'],
#  'VNO': ['VNO', 'Vornado Realty Trust'],
#  'HES': ['HES', 'Hess', 'Hess Corp'],
#  'ALK': ['ALK', 'Alaska Airgroup', 'Alaska Airgroup Inc'],
#  'BF': ['BF', 'Brown Forman', 'Brown Forman Corp'],
#  'OMC': ['OMC', 'Omnicom', 'Omnicom Group Inc'],
#  'HRL': ['HRL', 'Hormel Foods', 'Hormel Foods Corp'],
#  'ATO': ['ATO', 'Atmos Energy', 'Atmos Energy Corp'],
#  'MAS': ['MAS', 'Masco', 'Masco Corp'],
#  'FITB': ['FITB', 'Fifth Third Bancorp'],
#  'NUE': ['NUE', 'Nucor', 'Nucor Corp'],
#  'OXY': ['OXY', 'Occidental Petroleum', 'Occidental Petroleum Corp'],
#  'RF': ['RF', 'Regions Financial', 'Regions Financial Corp New'],
#  'MTB': ['M&T Bank', 'M&T Bank Corp', 'M And T Bank', 'MTB'],
#  'ROL': ['ROL', 'Rollins', 'Rollins Inc'],
#  'SHW': ['SHW', 'Sherwin Williams', 'Sherwin Williams Co'],
#  'BEN': ['BEN', 'Franklin Resources', 'Franklin Resources Inc'],
#  'AJG': ['AJG', 'Gallagher Arthur', 'Gallagher Arthur J & Co'],
#  'WMB': ['WMB', 'Williams Cos'],
#  'WFC': ['WFC', 'Wells Fargo & Co New', 'Wells Fargo'],
#  'NI': ['NI', 'Nisource', 'Nisource Inc'],
#  'APA': ['APA Corp', 'APA'],
#  'BDX': ['BDX', 'Becton Dickinson', 'Becton Dickinson & Co'],
#  'WY': ['WY', 'Weyerhaeuser', 'Weyerhaeuser Co'],
#  'DXC': ['DXC', 'DXC Technology', 'DXC Technology Co'],
#  'IFF': ['Flavors And Frag',
#   'IFF',
#   'International Flavors & Frag',
#   'International Flavors & Frag Inc'],
#  'TJX': ['TJX Companies', 'TJX'],
#  'CMI': ['CMI', 'Cummins', 'Cummins Inc'],
#  'PH': ['PH', 'Parker Hannifin', 'Parker Hannifin Corp'],
#  'PKI': ['PKI', 'Perkinelmer', 'Perkinelmer Inc'],
#  'SJM': ['SJM', 'Smucker JM', "Smucker's", 'Smucker'],
#  'JBHT': ['Hunt JB Transport',
#   'Hunt JB Transport Services',
#   'Hunt JB Transport Services Inc',
#   'JBHT'],
#  'HBAN': ['HBAN', 'Huntington Bancshares', 'Huntington Bancshares Inc'],
#  'SWK': ['SWK',
#   'Stanley Black & Decker',
#   'Stanley Black & Decker Inc',
#   'Stanley Black And Decker'],
#  'MCD': ['MCD',
#   'McD',
#   'McDonalds',
#   'Mcdonalds',
#   'Mcdonalds Corp',
#   "Mickey D's"],
#  'VFC': ['VF Corp', 'VFC'],
#  'ES': ['ES', 'Eversource Energy'],
#  'TFX': ['TFX', 'Teleflex', 'Teleflex Inc'],
#  'AVY': ['AVY', 'Avery Dennison', 'Avery Dennison Corp'],
#  'ADP': ['ADP', 'Automatic Data Processing', 'Automatic Data Processing Inc'],
#  'JCI': ['JCI', 'Johnson Controls Intl', 'Johnson Controls'],
#  'MMC': ['MMC',
#   'Marsh & Mclennan',
#   'Marsh & Mclennan Cos Inc',
#   'Marsh And Mclennan Cos'],
#  'SWKS': ['SWKS', 'Skyworks Solutions', 'Skyworks Solutions Inc'],
#  'CLX': ['CLX', 'Clorox', 'Clorox Co'],
#  'GPC': ['GPC', 'Genuine Parts', 'Genuine Parts Co'],
#  'HST': ['HST',
#   'Host Hotels & Resorts',
#   'Host Hotels & Resorts Inc',
#   'Host Hotels And Resorts'],
#  'KLAC': ['KLA Corp', 'KLAC'],
#  'JPM': ['Chase', 'JP Morgan', 'JPM', 'Jpmorgan Chase', 'Jpmorgan Chase & Co'],
#  'LRCX': ['LRCX', 'Lam Resh', 'Lam Resh Corp'],
#  'MCO': ['MCO', 'Moodys', 'Moodys Corp'],
#  'HUM': ['HUM', 'Humana', 'Humana Inc'],
#  'UNP': ['UNP', 'Union Pacific', 'Union Pacific Corp'],
#  'LNC': ['LNC', 'Lincoln National', 'Lincoln National Corp'],
#  'TGT': ['TGT', 'Target', 'Target Corp'],
#  'BK': ['BK',
#   'Bank Of New York Mellon',
#   'Bank Of New York Mellon Corp',
#   'BNY Mellon',
#   'BNYMellon'],
#  'DHR': ['DHR', 'Danaher', 'Danaher Corp'],
#  'LLY': ['LLY', 'Eli Lilly', 'Eli Lilly & Co', 'Lilly Eli'],
#  'TER': ['TER', 'Teradyne', 'Teradyne Inc'],
#  'SYY': ['SYY', 'Sysco', 'Sysco Corp'],
#  'MKC': ['MKC', 'Mccormick', 'Mccormick & Co Inc'],
#  'RHI': ['RHI', 'Robert Half', 'Robert Half International Inc'],
#  'J': ['J', 'Jacobs Solutions', 'Jacobs Solutions Inc'],
#  'EFX': ['EFX', 'Equifax', 'Equifax Inc'],
#  'GWW': ['GWW', 'Grainger WW', 'Grainger WW Inc'],
#  'LEN': ['LEN', 'Lennar', 'Lennar Corp'],
#  'HAS': ['HAS', 'Hasbro', 'Hasbro Inc'],
#  'IPG': ['IPG',
#   'Interpublic',
#   'Interpublic Group Cos',
#   'Interpublic Group Cos Inc'],
#  'MU': ['MU', 'Micron', 'Micron Technology', 'Micron Technology Inc'],
#  'PHM': ['PHM', 'Pulte', 'Pulte Group Inc'],
#  'WMT': ['WMT', 'Walmart', 'Walmart Inc'],
#  'CAG': ['CAG', 'Conagra Brands', 'Conagra Brands Inc'],
#  'ITW': ['ITW', 'Illinois Tool Works', 'Illinois Tool Works Inc'],
#  'BALL': ['BALL', 'Ball Corp'],
#  'NKE': ['NKE', 'Nike', 'Nike Inc'],
#  'NDSN': ['NDSN', 'Nordson', 'Nordson Corp'],
#  'AFL': ['AFL', 'Aflac', 'Aflac Inc'],
#  'NTRS': ['NTRS', 'Northern Trust', 'Northern Trust Corp'],
#  'FRT': ['FRT', 'Federal Realty Investment Tr', 'Federal Realty Investment'],
#  'LUV': ['LUV', 'Southwest Airlines', 'Southwest Airlines Co', 'SW Airline'],
#  'LNT': ['Alliant Energy', 'Alliant Energy Corp', 'LNT'],
#  'AXP': ['AXP', 'American Express', 'American Express Co', 'Amex'],
#  'TAP': ['Molson Coors Beverage',
#   'Molson Coors Beverage Co',
#   'Molsonors Beverage',
#   'TAP'],
#  'UDR': ['UDR', 'UDR Inc'],
#  'INTC': ['INTC', 'Intel', 'Intel Corp'],
#  'BAC': ['BAC',
#   'Bank Of America',
#   'Bank Of America Corp',
#   'Bank of America',
#   'BofA',
#   'BOA'],
#  'TRV': ['TRV', 'Travelers Companies', 'Travelers'],
#  'MDT': ['MDT', 'Medtronic', 'Medtronic Plc'],
#  'SNA': ['SNA', 'Snap On', 'Snap On Inc'],
#  'PNC': ['PNC Financial',
#   'PNC Financial Services',
#   'PNC Financial Services Grp',
#   'PNC'],
#  'PCAR': ['PCAR', 'Paccar', 'Paccar Inc'],
#  'LUMN': ['LUMN', 'Lumen Techologies', 'Lumen Techologies Inc'],
#  'FDX': ['FDX', 'Fedex', 'Fedex Corp'],
#  'ADI': ['ADI', 'Analog Devices', 'Analog Devices Inc'],
#  'NWL': ['NWL', 'Newell Brands', 'Newell Brands Inc'],
#  'AMD': ['AMD', 'Advanced Micro Devices', 'Advanced Micro Devices Inc'],
#  'LOW': ['LOW', 'Lowes Companies', 'Lowes Companies Inc'],
#  'BIO': ['BIO', 'Bio Rad Laboratories', 'Bio Rad Laboratories Inc'],
#  'PAYX': ['PAYX', 'Paychex', 'Paychex Inc'],
#  'AON': ['AON', 'Aon', 'Aon Plc New'],
#  'TMO': ['TMO', 'Thermo Fisher Scientific', 'Thermo Fisher Scientific Inc'],
#  'CSX': ['CSX Corp', 'CSX'],
#  'GL': ['GL', 'Globe Life', 'Globe Life Inc'],
#  'WST': ['WST',
#   'West Pharmaceutical',
#   'West Pharmaceutical Services',
#   'West Pharmaceutical Services Inc'],
#  'BRO': ['BRO', 'Brown & Brown', 'Brown & Brown Inc', 'Brown And Brown'],
#  'CI': ['CI', 'Cigna', 'Cigna Corp New'],
#  'BBWI': ['BBWI',
#   'Bath & Body Works',
#   'Bath & Body Works Inc',
#   'Bath And Body Works'],
#  'NSC': ['NSC', 'Norfolk Southern', 'Norfolk Southern Corp'],
#  'PGR': ['PGR', 'Progressive Corp', 'Progressive'],
#  'PSA': ['PSA', 'Public Storage'],
#  'D': ['D', 'Dominion Energy', 'Dominion Energy Inc'],
#  'KEY': ['KEY', 'Keycorp', 'Keycorp New'],
#  'AOS': ['AOS', 'Smith AO'],
#  'COO': ['COO', 'Cooper Companies', 'Cooper Companies Inc'],
#  'VZ': ['VZ',
#   'Verizon',
#   'Verizon Communications',
#   'Verizon Communications Inc'],
#  'WELL': ['WELL', 'Welltower', 'Welltower Inc'],
#  'T': ['AT&T', 'AT&T Inc'],
#  'USB': ['US Bancorp', 'USB'],
#  'HD': ['HD', 'Home Depot', 'Home Depot Inc'],
#  'WDC': ['WDC', 'Western Digital', 'Western Digital Corp'],
#  'AIG': ['AIG', 'American International Group'],
#  'PEAK': ['Healthpeak Properties', 'Healthpeak Properties Inc', 'PEAK'],
#  'MS': ['MS', 'Morgan Stanley', 'Morgan Stanley Dean Witter & Co'],
#  'RJF': ['RJF', 'Raymond James Financial', 'Raymond James'],
#  'STZ': ['Constellation Brands', 'Constellation Brands Inc', 'STZ'],
#  'C': ['C', 'Citigroup', 'Citi'],
#  'ECL': ['ECL', 'Ecolab', 'Ecolab Inc'],
#  'TFC': ['TFC', 'Truist Financial', 'Truist Financial Corp'],
#  'STT': ['STT', 'State Street', 'State Street Corp'],
#  'SYK': ['SYK', 'Stryker', 'Stryker Corp'],
#  'BKR': ['BKR', 'Baker Hughes', 'Baker Hughes Co'],
#  'CCL': ['CCL', 'Carnival', 'Carnival Corp'],
#  'SCHW': ['SCHW', 'Charles Schwab'],
#  'PXD': ['PXD', 'Pioneer Natural Resources', 'Pioneer Natural Resources Co'],
#  'ADBE': ['ADBE', 'Adobe', 'Adobe Inc'],
#  'IEX': ['IEX', 'Idex', 'Idex Corp'],
#  'GEN': ['GEN', 'Gen Digital', 'Gen Digital Inc'],
#  'TECH': ['Bio Techne', 'Bio Techne Corp', 'TECH'],
#  'VTR': ['VTR', 'Ventas', 'Ventas Inc'],
#  'EOG': ['EOG', 'Eog Resources', 'Eog Resources Inc'],
#  'EA': ['EA', 'Electronic Arts', 'Electronic Arts Inc'],
#  'PTC': ['PTC'],
#  'CSCO': ['CSCO', 'Cisco', 'Cisco Systems', 'Cisco Systems Inc'],
#  'CTRA': ['CTRA', 'Coterra Energy', 'Coterra Energy Inc'],
#  'HOLX': ['HOLX', 'Hologic', 'Hologic Inc'],
#  'TYL': ['TYL', 'Tyler Technologies', 'Tyler Technologies Inc'],
#  'PARA': ['PARA', 'Paramount Global', 'Paramount'],
#  'TRMB': ['TRMB', 'Trimble', 'Trimble Inc'],
#  'AZO': ['AZO', 'Autozone', 'Autozone Inc'],
#  'REGN': ['REGN', 'Regeneron Pharmaceuticals', 'Regeneron'],
#  'IDXX': ['IDEXX Laboratories', 'IDEXX Labs', 'IDXX'],
#  'AES': ['AES Corp', 'AES'],
#  'VRTX': ['VRTX', 'Vertex Pharmaceuticals', 'Vertex'],
#  'ZBRA': ['ZBRA', 'Zebra', 'Zebra Technologies', 'Zebra Technologies Corp'],
#  'BIIB': ['BIIB', 'Biogen', 'Biogen Inc'],
#  'ODFL': ['ODFL', 'Old Dominion Freight Line', 'Old Dominion'],
#  'KIM': ['KIM', 'Kimco Realty', 'Kimco'],
#  'QCOM': ['QCOM', 'Qualcomm', 'Qualcomm Inc'],
#  'GILD': ['GILD', 'Gilead Sciences', 'Gilead'],
#  'ROP': ['ROP', 'Roper', 'Roper Technologies', 'Roper Technologies Inc'],
#  'SNPS': ['SNPS', 'Synopsys', 'Synopsys Inc'],
#  'MHK': ['MHK', 'Mohawk', 'Mohawk Industries', 'Mohawk Industries Inc'],
#  'BSX': ['BSX', 'Boston Scientific', 'Boston Scientific Corp'],
#  'STE': ['STE', 'Steris', 'Steris Plc New'],
#  'DHI': ['DR Horton', 'DR Horton Inc', 'DHI'],
#  'SBUX': ['SBUX', 'Starbucks', 'Starbucks Corp'],
#  'TSN': ['TSN', 'Tyson Foods', 'Tyson Foods Inc'],
#  'INTU': ['INTU', 'Intuit', 'Intuit Inc'],
#  'MCHP': ['MCHP',
#   'Microchip',
#   'Microchip Technology',
#   'Microchip Technology Inc'],
#  'CB': ['CB', 'Chubb', 'Chubb Ltd'],
#  'ORLY': ['O Reilly Automotive', 'Reilly', 'ORLY'],
#  'RCL': ['RCL', 'Royal Caribbean Cruises', 'Royal Caribbean'],
#  'ALL': ['ALL', 'Allstate', 'Allstate Corp'],
#  'CPT': ['CPT', 'Camden Property Trust'],
#  'BWA': ['BWA', 'Borgwarner', 'Borgwarner Inc'],
#  'EQR': ['EQR', 'Equity Residential'],
#  'UHS': ['UHS', 'Universal Health Services', 'Universal Health Services Inc'],
#  'ATVI': ['ATVI', 'Activision Blizzard', 'Activision', 'Blizzard'],
#  'IT': ['Gartner', 'Gartner Inc', 'IT'],
#  'REG': ['REG', 'Regency Centers', 'Regency Centers Corp'],
#  'NVR': ['NVR Inc', 'NVR'],
#  'INCY': ['INCY', 'Incyte', 'Incyte Corp'],
#  'EMN': ['EMN', 'Eastman Chemical', 'Eastman Chemical Co'],
#  'SPG': ['SPG', 'Simon Property', 'Simon Property Group Inc New'],
#  'MAA': ['MAA', 'Mid America Apt', 'Mid America Apartment'],
#  'ALB': ['ALB', 'Albemarle', 'Albemarle Corp'],
#  'MLM': ['MLM', 'Martin Marietta Materials', 'Martin Marietta'],
#  'TSCO': ['TSCO', 'Tractor Supply'],
#  'CPRT': ['CPRT', 'Copart', 'Copart Inc'],
#  'AVB': ['AVB', 'Avalonbay Communities', 'Avalonbay'],
#  'ESS': ['ESS', 'Essex Property Trust', 'Essex Property Trust Inc'],
#  'O': ['O', 'Realty Income', 'Realty Income Corp'],
#  'COF': ['COF', 'Capital One Financial', 'Capital One'],
#  'MCK': ['MCK', 'Mckesson HBOC', 'Mckesson'],
#  'DLTR': ['DLTR', 'Dollar Tree', 'Dollar Tree Inc'],
#  'ABC': ['ABC', 'Amerisourcebergen', 'Amerisourcebergen Corp'],
#  'DRI': ['DRI', 'Darden Restaurants', 'Darden Restaurants Inc'],
#  'WAB': ['WAB', 'Wabtec', 'Wabtec Corp'],
#  'DISH': ['DISH', 'Dish Network'],
#  'RMD': ['RMD', 'Resmed', 'Resmed Inc'],
#  'FCX': ['FCX', 'Freeport Mcmoran', 'Freeport Mcmoran Inc'],
#  'ACGL': ['ACGL', 'Arch Capital', 'Arch Capital Group'],
#  'RE': ['Everest Realty', 'Everest Group', 'RE'],
#  'DVA': ['DVA', 'Davita', 'Davita Inc'],
#  'POOL': ['POOL', 'Pool Corp'],
#  'HSIC': ['HSIC', 'Henry Schein'],
#  'NTAP': ['NTAP', 'Netapp', 'Netapp Inc'],
#  'EL': ['EL', 'Estee Lauder'],
#  'WAT': ['WAT', 'Waters', 'Waters Corp'],
#  'HIG': ['HIG', 'Hartford Financial', 'Hartford Services'],
#  'IRM': ['IRM', 'Iron Mountain', 'Iron Mountain Inc New'],
#  'BRK': ['BRK', 'Berkshire Hathaway', 'Buffet', 'BRK.A', 'BRK.B'],
#  'FDS': ['FDS', 'Factset Research', 'Factset'],
#  'ANSS': ['ANSS', 'Ansys', 'Ansys Inc'],
#  'ZION': ['ZION', 'Zions'],
#  'STLD': ['STLD', 'Steel Dynamics', 'Steel Dynamics Inc'],
#  'DGX': ['DGX', 'Quest Diagnostics'],
#  'ROK': ['ROK', 'Rockwell Automation', 'Rockwell Automation Inc'],
#  'TTWO': ['TTWO', 'Take Two Interactive'],
#  'ARE': ['ARE', 'Alexandria Real'],
#  'APH': ['APH', 'Amphenol', 'Amphenol Corp New'],
#  'AMZN': ['AMZN', 'Amazon', 'Amazon.com', 'Bezos'],
#  'QRVO': ['QRVO', 'Qorvo', 'Qorvo Inc'],
#  'BXP': ['BXP', 'Boston Properties', 'Boston Properties Inc'],
#  'RL': ['RL', 'Ralph Lauren', 'Ralph Lauren Corp'],
#  'AME': ['AME', 'Ametek', 'Ametek Inc New'],
#  'VLO': ['VLO', 'Valero Energy', 'Valero Energy Corp New'],
#  'YUM': ['YUM', 'Yum Brands', 'Yum Brands Inc'],
#  'CHRW': ['CHRW', 'Ch Robinson Worldwide', 'C.H. Robinson', 'Robinson'],
#  'PLD': ['PLD', 'Prologis', 'Prologis Inc'],
#  'MTD': ['MTD', 'Mettler Toledo', 'Mettler Toledo International Inc'],
#  'ADSK': ['ADSK', 'Autodesk', 'Autodesk Inc'],
#  'URI': ['URI', 'United Rentals', 'United Rentals Inc'],
#  'VRSN': ['VRSN', 'Verisign', 'Verisign Inc'],
#  'PWR': ['PWR', 'Quanta', 'Quanta Services', 'Quanta Services Inc'],
#  'MAR': ['MAR', 'Marriott', 'Marriott International Inc New'],
#  'BBY': ['BBY', 'Best Buy', 'Best Buy Company Inc'],
#  'SEE': ['SEE', 'Sealed Air', 'Sealed Air Corp New'],
#  'AMT': ['AMT', 'American Tower', 'American Tower Corp New'],
#  'SRE': ['SRE', 'Sempra Energy'],
#  'CTSH': ['CTSH', 'Cognizant'],
#  'RSG': ['RSG', 'Republic Services', 'Republic Services Inc'],
#  'CSGP': ['CSGP', 'Costar', 'Costar Group Inc'],
#  'CCI': ['CCI', 'Crown Castle', 'Crown Castle Inc'],
#  'EBAY': ['EBAY', 'Ebay', 'Ebay Inc'],
#  'NVDA': ['NVDA', 'Nvidia', 'Nvidia Corp', 'Jensen Huang'],
#  'BKNG': ['BKNG', 'Booking', 'Booking Holdings Inc', 'Booking.com'],
#  'GS': ['GS', 'Goldman', 'Goldman Sachs', 'Goldman Sachs Group Inc'],
#  'FFIV': ['F5', 'FFIV'],
#  'JNPR': ['JNPR', 'Juniper Networks', 'Juniper Networks Inc'],
#  'SBAC': ['SBA Communications', 'SBAC'],
#  'COST': ['COST', 'Costco'],
#  'DVN': ['DVN', 'Devon Energy', 'Devon Energy Corp New'],
#  'BLK': ['BLK', 'Blackrock', 'Blackrock Inc'],
#  'AKAM': ['AKAM', 'Akamai', 'Akamai Technologies', 'Akamai Technologies Inc'],
#  'A': ['A', 'Agilent', 'Agilent Technologies', 'Agilent Technologies Inc'],
#  'TDY': ['TDY', 'Teledyne', 'Teledyne Technologies'],
#  'UPS': ['UPS', 'United Parcel Service', 'United Postal Service'],
#  'PKG': ['PKG', 'Packaging America', 'Packaging Corp America'],
#  'EW': ['EW', 'Edwards Lifesciences', 'Edwards Lifesciences Corp'],
#  'EXPD': ['EXPD', 'Expeditors International'],
#  'MET': ['MET', 'Metlife', 'Metlife Inc'],
#  'MNST': ['MNST', 'Monster Beverage', 'Monster'],
#  'ON': ['ON', 'On Semiconductor', 'On Semiconductor Corp'],
#  'CRL': ['CRL', 'Charles River Labs Intl', 'Charles River'],
#  'ISRG': ['ISRG', 'Intuitive Surgical', 'Intuitive Surgical Inc'],
#  'ILMN': ['ILMN', 'Illumina', 'Illumina Inc'],
#  'TPR': ['TPR', 'Tapestry', 'Tapestry Inc'],
#  'JKHY': ['Henry Jack & Assoc', 'Henry Jack', 'Henry Jack And Assoc', 'JKHY'],
#  'GRMN': ['GRMN', 'Garmin', 'Garmin Ltd'],
#  'ALGN': ['ALGN', 'Align', 'Align Technology', 'Align Technology Inc'],
#  'GPN': ['GPN', 'Global Payments', 'Global Payments Inc'],
#  'FIS': ['FIS',
#   'Fidelity National Info Svcs',
#   'Fidelity National Information'],
#  'MDLZ': ['MDLZ', 'Mondelez', 'Mondelez International Inc'],
#  'WTW': ['WTW', 'Willis Towers Watson Pub', 'Willis Towers Watson Pub Ltd Co'],
#  'ZBH': ['ZBH', 'Zimmer Biomet', 'Zimmer Biomet Holdings Inc'],
#  'ACN': ['ACN', 'Accenture'],
#  'ELV': ['ELV', 'Elevance Health', 'Elevance Health Inc'],
#  'PFG': ['PFG', 'Principal Financial', 'Principal Financial Group Inc'],
#  'AAP': ['AAP', 'Advance Auto Parts', 'Advanced Auto Parts'],
#  'PRU': ['PRU', 'Prudential'],
#  'CNC': ['CNC', 'Centene Corp Del', 'Centene Del'],
#  'NFLX': ['NFLX', 'Netflix', 'Netflix Inc'],
#  'KMX': ['Carmax', 'Carmax Inc', 'KMX'],
#  'CMCSA': ['CMCSA', 'Comcast', 'Comcast Corp New'],
#  'WYNN': ['WYNN', 'Wynn Resorts', 'Wynn Resorts Ltd'],
#  'EQIX': ['EQIX', 'Equinix', 'Equinix Inc'],
#  'CME': ['CME', 'CME Group'],
#  'STX': ['STX',
#   'Seagate',
#   'Seagate Technology',
#   'Seagate Technology Holdings Plc'],
#  'MOH': ['MOH', 'Molina Healthcare', 'Molina'],
#  'LKQ': ['LKQ Corp', 'LKQ'],
#  'AIZ': ['AIZ', 'Assurant', 'Assurant Inc'],
#  'NRG': ['NRG Energy', 'NRG'],
#  'SBNY': ['SBNY', 'Signature Bank New York', 'Signature Bank'],
#  'CBRE': ['CBRE Group', 'CBRE'],
#  'CRM': ['CRM', 'Salesforce', 'Salesforce Inc'],
#  'DPZ': ['DPZ', 'Dominos'],
#  'EXR': ['EXR', 'Extra Space Storage', 'Extra Space Storage Inc'],
#  'GOOGL': ['Alphabet', 'Alphabet Inc', 'GOOGL', 'Google'],
#  'DLR': ['DLR', 'Digital Realty Trust', 'Digital Realty Trust Inc'],
#  'MOS': ['MOS', 'Mosaic', 'Mosaic Co New'],
#  'MKTX': ['MKTX', 'Marketaxess Hldgs', 'Marketaxess'],
#  'MPWR': ['MPWR', 'Monolithic Power', 'Monolithic Pwr'],
#  'LVS': ['LVS', 'Las Vegas Sands', 'Las Vegas Sands Corp'],
#  'CE': ['CE', 'Celanese Corp Del', 'Celanese'],
#  'NDAQ': ['NDAQ', 'Nasdaq', 'Nasdaq Inc'],
#  'DXCM': ['DXCM', 'Dexcom', 'Dexcom Inc'],
#  'EXPE': ['EXPE', 'Expedia', 'Expedia Group Inc'],
#  'CF': ['CF Industries', 'CF'],
#  'AMP': ['AMP', 'Ameriprise Financial', 'Ameriprise'],
#  'ICE': ['ICE',
#   'Intercontinentalexchange',
#   'Intercontinentalexchange Grp Inc'],
#  'LYV': ['LYV', 'Live Nation Entertainment', 'Live Nation Entertainment Inc'],
#  'CMG': ['CMG', 'Chipotle'],
#  'UAL': ['UAL', 'United Airlines', 'United Airlines Holdings Inc'],
#  'TDG': ['TDG', 'Transdigm', 'Transdigm Group Inc'],
#  'MA': ['MA', 'Mastercard', 'Mastercard Inc'],
#  'LDOS': ['LDOS', 'Leidos', 'Leidos Holdings Inc'],
#  'ROST': ['ROST', 'Ross'],
#  'FSLR': ['FSLR', 'First Solar', 'First Solar Inc'],
#  'BR': ['BR', 'Broadridge Financial Solutns', 'Broadridge'],
#  'DAL': ['DAL', 'Delta Air Lines', 'Delta'],
#  'TMUS': ['T Mobile', 'TMUS'],
#  'DFS': ['DFS', 'Discover Financial', 'Discover'],
#  'TEL': ['TE Connectivity', 'TEL'],
#  'ULTA': ['ULTA', 'Ulta Beauty', 'Ulta'],
#  'MSCI': ['MSCI'],
#  'PM': ['PM', 'Philip Morris', 'Philip Morris International Inc'],
#  'V': ['V', 'Visa', 'Visa Inc'],
#  'AWK': ['AWK', 'American Water Works'],
#  'UNH': ['UNH', 'Unitedhealth', 'Unitedhealth Group Inc'],
#  'AVGO': ['AVGO', 'Broadcom', 'Broadcom Inc'],
#  'VRSK': ['VRSK', 'Verisk Analytics', 'Verisk Analytics Inc'],
#  'DG': ['DG', 'Dollar General', 'Dollar General Corp New'],
#  'FTNT': ['FTNT', 'Fortinet', 'Fortinet Inc'],
#  'GNRC': ['GNRC', 'Generac', 'Generac Holdings Inc'],
#  'CBOE': ['CBOE Global Markets', 'CBOE'],
#  'TSLA': ['TSLA', 'Tesla', 'Tesla Inc', 'Tesla Motors'],
#  'EME': ['EME', 'Emcor'],
#  'HOOD': ['HOOD', 'Robinhood Markets'],
#  'APP': ['APP', 'Applovin'],
#  'IBKR': ['IBKR', 'Interactive Brokers'],
#  'SQ': ['Block', 'SQ'],
#  'TTD': ['TTD', 'Trade Desk'],
#  'DDOG': ['DDOG', 'Datadog'],
#  'COIN': ['COIN', 'Coinbase'],
#  'DASH': ['DASH', 'Doordash'],
#  'TKO': ['TKO', 'Tko', 'Tko Group', 'Tko Group Holdings'],
#  'WSM': ['WSM', 'Williams-Sonoma'],
#  'EXE': ['EXE', 'Expand Energy'],
#  'APO': ['APO', 'Apollo Global'],
#  'WDAY': ['WDAY', 'Workday'],
#  'LII': ['LII', 'Lennox', 'Lennox International'],
#  'TPL': ['TPL', 'Texas Pacific Land', 'Texas Pacific Land Corporation'],
#  'PLTR': ['PLTR', 'Palantir', 'Palantir Technologies'],
#  'DELL': ['DELL', 'Dell', 'Dell Technologies'],
#  'ERIE': ['ERIE', 'Erie Indemnity'],
#  'KKR': ['KKR'],
#  'CRWD': ['CRWD', 'Crowdstrike'],
#  'GDDY': ['GDDY', 'Godaddy'],
#  'VST': ['VST', 'Vistra'],
#  'GEV': ['GEV', 'Ge Vernova'],
#  'SOLV': ['SOLV', 'Solventum'],
#  'SMCI': ['SMCI', 'Supermicro'],
#  'DECK': ['DECK', 'Deckers Brands'],
#  'UBER': ['UBER', 'Uber'],
#  'JBL': ['JBL', 'Jabil'],
#  'BLDR': ['BLDR', 'Builders Firstsource'],
#  'HUBB': ['HUBB', 'Hubbell'],
#  'LULU': ['LULU', 'Lululemon Athletica'],
#  'VLTO': ['VLTO', 'Veralto'],
#  'BX': ['BX', 'Blackstone'],
#  'ABNB': ['ABNB', 'Airbnb'],
#  'KVUE': ['KVUE', 'Kenvue'],
#  'PANW': ['PANW', 'Palo Alto Networks'],
#  'AXON': ['AXON', 'Axon Enterprise'],
#  'FICO': ['FICO', 'Fair Isaac'],
#  'BG': ['BG', 'Bunge Global'],
#  'PODD': ['Insulet', 'PODD'],
#  'GEHC': ['GEHC', 'Ge Healthcare']}

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /Users/yiruoli/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
def split_sentences(text: str):
    return nltk.sent_tokenize(text)

# %%
# ---- Drop-in: extract sentences mentioning each company from your `articles` DF ----
def _strip_html(x: str) -> str:
    x = html.unescape(x or "")
    return re.sub(r"<[^>]+>", " ", x)

# simple sentence splitter that works well on newsy English
_SENT_SPLIT = re.compile(r'(?<!\b[A-Z])(?<=[.!?])\s+(?=[A-Z0-9])')

def _compile_alias_regex(aliases: Iterable[str]) -> re.Pattern:
    al = []
    for a in aliases:
        a = a.strip()
        if not a: 
            continue
        a = r"\s+".join(map(re.escape, a.split()))
        al.append(fr"\b{a}\b(?:'s|’s)?")
    return re.compile("|".join(al), flags=re.IGNORECASE) if al else re.compile(r"$^")


def _mark_alias_in_sentence(sent: str, aliases: Iterable[str]) -> str:
    if not isinstance(sent, str) or not sent.strip():
        return sent

    original = sent
    for a in aliases:
        a = a.strip()
        if not a:
            continue
        patt = r"\b" + r"\s+".join(map(re.escape, a.split())) + r"\b(?:'s|’s)?"
        regex = re.compile(patt, flags=re.IGNORECASE)
        if regex.search(original):
            return regex.sub(" [TGT] ", original, count=1)

    return original

def extract_company_sentences_from_text(
    text: str,
    aliases: Iterable[str],
    window: int,
    max_len: int
) -> List[str]:
    text = _strip_html(text)

    sents = re.split(r'(?<=[.!?])\s+', text)
    sents = [s for s in sents if s.strip()] 

    pat = _compile_alias_regex(aliases)

    hits_idx = [i for i, s in enumerate(sents) if pat.search(s)]
    chunks = []

    for i in hits_idx:
        lo, hi = max(0, i - window), min(len(sents), i + window + 1)

        window_sents = sents[lo:hi]

        center_rel_idx = i - lo
        center_sent = window_sents[center_rel_idx]
        center_marked = _mark_alias_in_sentence(center_sent, aliases)
        window_sents = list(window_sents)
        window_sents[center_rel_idx] = center_marked

        chunk = " ".join(window_sents).strip()
        chunks.append(chunk[:max_len])

    return chunks



def get_company_mentions(
    articles: pd.DataFrame,
    alias_map: Dict[str, Iterable[str]],
    text_col: str = "body",      # or "summary" / "title"
    window: int = 0, 
    max_len: int = 500, 
) -> pd.DataFrame:
    rows = []
    for tic, aliases in alias_map.items():
        subset = articles.loc[articles["ticker"] == tic]
        for idx, r in subset.iterrows():
            original_idx = r["article_id"]
            text = r.get(text_col, "") or ""
            for snip in extract_company_sentences_from_text(
                text,
                aliases,
                window=window,
                max_len=max_len
            ):
                rows.append({
                    "ticker": tic,
                    "pub_date": r.get("pub_date"),
                    "article_id": r.get("id"),
                    "title": r.get("title"),
                    "url": r.get("url"),
                    "snippet": snip,
                    "article_row": original_idx,   
                })
    return pd.DataFrame(rows)

# %%
news2 = news.copy()
news2["full_text"] = (
    news2["title"].fillna("").astype(str).str.replace("nan", "", regex=False)
    + " "
    + news2["body"].fillna("").astype(str).str.replace("nan", "", regex=False)
)

compiled_patterns = {
    ticker: _compile_alias_regex(aliases)
    for ticker, aliases in TICKER_MAP.items()
}

expanded_dfs = []

for ticker, pat in compiled_patterns.items():
    mask = news2["full_text"].str.contains(pat)
    sub = news2.loc[mask].copy()
    if sub.empty:
        continue

    sub["ticker"] = ticker
    expanded_dfs.append(sub)

news3_with_tickers = (
    pd.concat(expanded_dfs, ignore_index=True)
    .drop(columns=["full_text"])
)
news3_with_tickers
# Out:
#        version https://git-lfs.github.com/spec/v1  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 361179                                        NaN
# 361180                                        NaN
# 361181                                        NaN
# 361182                                        NaN
# 361183                                        NaN
#
#                                                       url  \
# 0       https://www.theguardian.com/global-development...
# 1       https://www.theguardian.com/technology/2017/fe...
# 2       https://www.theguardian.com/business/2017/mar/...
# 3       https://www.theguardian.com/technology/2017/ap...
# 4       https://www.theguardian.com/technology/2017/ap...
# ...                                                   ...
# 361179  https://www.theguardian.com/business/2022/sep/...
# 361180  https://www.theguardian.com/business/2022/sep/...
# 361181  https://www.theguardian.com/business/2022/sep/...
# 361182  https://www.theguardian.com/business/2022/sep/...
# 361183  https://www.theguardian.com/business/2021/aug/...
#
#                                                     title  \
# 0       World's eight richest people have same wealth ...
# 1       Meet the rightwing power players lurking benea...
# 2       Has the tech bubble peaked? Signs that the sta...
# 3       Palantir to pay $1.7m over accusation it discr...
# 4       Google accused of 'extreme' gender pay discrim...
# ...                                                   ...
# 361179  Could Wael Sawan usher in a renewable revoluti...
# 361180  Chris O’Shea: Centrica chief executive with a ...
# 361181  Shell boss Ben van Beurden prepares to stand d...
# 361182  Shell appoints Wael Sawan to replace outgoing ...
# 361183  PCR Covid test firm with links to former minis...
#
#                     pub_date  \
# 0       2017-01-16T00:01:08Z
# 1       2017-02-10T10:00:49Z
# 2       2017-03-17T07:02:02Z
# 3       2017-04-26T19:17:39Z
# 4       2017-04-07T22:48:42Z
# ...                      ...
# 361179  2022-09-15T15:29:14Z
# 361180  2022-09-10T15:00:06Z
# 361181  2022-09-02T08:18:45Z
# 361182  2022-09-15T11:51:39Z
# 361183  2021-08-22T12:58:33Z
#
#                                                   summary  \
# 0       A new report by Oxfam warns of the growing and...
# 1       Despite promoting an image of innovative icono...
# 2       Startups are beginning to run out of money and...
# 3       Government lawsuit against the huge Silicon Va...
# 4       Allegations of possible employment violations ...
# ...                                                   ...
# 361179  Campaigners hope to see a radical shift under ...
# 361180  The energy boss is committed to nuclear and re...
# 361181  Energy firm shortlists four internal candidate...
# 361182  Energy firm’s head of integrated gas and renew...
# 361183  Exclusive: travellers let down by private prov...
#
#                                                      body  article_id ticker
# 0       The world’s eight richest billionaires control...         193   ORCL
# 1       When a group of 97 technology companies filed ...         712   ORCL
# 2       If you were looking for an apartment in the Ba...        1082   ORCL
# 3       Palantir, a Silicon Valley company with ties t...        1465   ORCL
# 4       Google has discriminated against its female em...        1653   ORCL
# ...                                                   ...         ...    ...
# 361179  Ben van Beurden sat stony faced as climate act...       31098     BG
# 361180  Even for an executive in the eye of the gather...       31132     BG
# 361181  Shell’s long-serving chief executive, Ben van ...       31234     BG
# 361182  Shell has appointed Wael Sawan, a 25-year comp...       31281     BG
# 361183  A Covid-19 testing company co-owned by a forme...       25015   PODD
#
# [361184 rows x 8 columns]

# %%
news3_with_tickers = news3_with_tickers.dropna(subset=["body"]).copy()

# %%
mentions = get_company_mentions(news3_with_tickers, TICKER_MAP, text_col="body", window=WINDOW, max_len = MAX_CHAR)
mentions
# Out:
#         ticker              pub_date article_id  \
# 0         ORCL  2017-01-16T00:01:08Z       None
# 1         ORCL  2017-02-10T10:00:49Z       None
# 2         ORCL  2017-03-17T07:02:02Z       None
# 3         ORCL  2017-04-26T19:17:39Z       None
# 4         ORCL  2017-04-26T19:17:39Z       None
# ...        ...                   ...        ...
# 2228866     BG  2022-09-10T15:00:06Z       None
# 2228867     BG  2022-09-02T08:18:45Z       None
# 2228868     BG  2022-09-15T11:51:39Z       None
# 2228869   PODD  2021-08-22T12:58:33Z       None
# 2228870   PODD  2021-08-22T12:58:33Z       None
#
#                                                      title  \
# 0        World's eight richest people have same wealth ...
# 1        Meet the rightwing power players lurking benea...
# 2        Has the tech bubble peaked? Signs that the sta...
# 3        Palantir to pay $1.7m over accusation it discr...
# 4        Palantir to pay $1.7m over accusation it discr...
# ...                                                    ...
# 2228866  Chris O’Shea: Centrica chief executive with a ...
# 2228867  Shell boss Ben van Beurden prepares to stand d...
# 2228868  Shell appoints Wael Sawan to replace outgoing ...
# 2228869  PCR Covid test firm with links to former minis...
# 2228870  PCR Covid test firm with links to former minis...
#
#                                                        url  \
# 0        https://www.theguardian.com/global-development...
# 1        https://www.theguardian.com/technology/2017/fe...
# 2        https://www.theguardian.com/business/2017/mar/...
# 3        https://www.theguardian.com/technology/2017/ap...
# 4        https://www.theguardian.com/technology/2017/ap...
# ...                                                    ...
# 2228866  https://www.theguardian.com/business/2022/sep/...
# 2228867  https://www.theguardian.com/business/2022/sep/...
# 2228868  https://www.theguardian.com/business/2022/sep/...
# 2228869  https://www.theguardian.com/business/2021/aug/...
# 2228870  https://www.theguardian.com/business/2021/aug/...
#
#                                                    snippet  article_row
# 0        Oxfam said the world’s poorest 50% owned the s...          193
# 1        Rodgers and McNealy combined the standard smal...          712
# 2        When you’ve seen your income go down by 80% as...         1082
# 3        Trump’s chief strategist, Steve Bannon, has pr...         1465
# 4        An official with the department, which is seek...         1465
# ...                                                    ...          ...
# 2228866  Born in Kirkcaldy, Fife, O’Shea studied accoun...        31132
# 2228867  His departure would end a near-40-year career ...        31234
# 2228868  “Ben can look back with great pride on an extr...        31281
# 2228869  “I’ve called them three or four times, whereup...        25015
# 2228870  It cost me £168 on top of everything else.” In...        25015
#
# [2228871 rows x 7 columns]

# %%
BAD_TICKERS = {"A", "ON", "IT", "HAS", "ARE",
               "ALL", "NOW", "SEE", "WELL", "COST",
               "RE", "V", "C", "F", "TECH"}  

#unsure: PM, D, O, FAST, PEAK, SO, LOW, KEY

mentions_clean = mentions[~mentions["ticker"].isin(BAD_TICKERS)].copy()

ticker_counts_clean = (
    mentions_clean["ticker"]
    .value_counts()
    .reset_index()
    .rename(columns={"index": "ticker", "ticker": "count"})
)

ticker_counts_clean

# %% [markdown]
# ### Here I ran the FinABSA.py on GPU, after getting the result, process the following for the final score

# %%
df = pd.read_csv('../data/top_50_absa_2024.csv')

# %%
def to_dict(x):
    if isinstance(x, dict):
        return x
    try:
        return ast.literal_eval(x)
    except:
        return None

def normalize_label(prob_dict):
    if not isinstance(prob_dict, dict) or len(prob_dict) == 0:
        return None
    return max(prob_dict, key=prob_dict.get)

df["absa_prob_dict"] = df["absa_probs"].apply(to_dict)
df["label_clean"] = df["absa_prob_dict"].apply(normalize_label)

# %% [markdown]
# This function computes different scores in several methods to choose from for later strategy generation

# %%
def extract_probs(d):
    if not isinstance(d, dict):
        return pd.Series(
            {"POS_prob": np.nan, "NEU_prob": np.nan, "NEG_prob": np.nan}
        )
    return pd.Series(
        {
            "POS_prob": d.get("POSITIVE", 0.0),
            "NEU_prob": d.get("NEUTRAL", 0.0),
            "NEG_prob": d.get("NEGATIVE", 0.0),
        }
    )

def get_group_date(group):
    vals = group["date"].dropna().unique()
    if len(vals) == 0:
        return None
    if len(vals) == 1 and not isinstance(vals[0], (list, pd.Series, np.ndarray)):
        return vals[0]

    v = group["date"].iloc[0]
    if isinstance(v, (pd.Series, list, np.ndarray)):
        if len(v) == 0:
            return None
        return v[0]
    else:
        return v

def _implied_from_dict(d):
    if d is None:
        return None
    if any(v is None for v in d.values()):
        return None
    key = max(d, key=d.get)   # 'positive' / 'neutral' / 'negative'
    return key.upper()        # 'POSITIVE' / 'NEUTRAL' / 'NEGATIVE'

def analyze_score_article(df):
    results = []

    for (article_id, ticker), group in df.groupby(["article_row", "ticker"]):
        g = group.copy()

        g[["POS_prob", "NEU_prob", "NEG_prob"]] = \
            g["absa_prob_dict"].apply(extract_probs)

        confidences = g[["POS_prob", "NEU_prob", "NEG_prob"]].max(axis=1)

        if confidences.isna().all() or confidences.sum() == 0:
            weighted_pos = weighted_neu = weighted_neg = np.nan
        else:
            weighted_pos = (g["POS_prob"] * confidences).sum() / confidences.sum()
            weighted_neu = (g["NEU_prob"] * confidences).sum() / confidences.sum()
            weighted_neg = (g["NEG_prob"] * confidences).sum() / confidences.sum()

        if np.isnan(weighted_pos) or np.isnan(weighted_neg):
            weighted_score = np.nan
        else:
            weighted_score = weighted_pos - weighted_neg

        weighted_softmax = {
            "positive": float(weighted_pos) if not np.isnan(weighted_pos) else None,
            "neutral":  float(weighted_neu) if not np.isnan(weighted_neu) else None,
            "negative": float(weighted_neg) if not np.isnan(weighted_neg) else None,
        }

        simple_pos = g["POS_prob"].mean()
        simple_neu = g["NEU_prob"].mean()
        simple_neg = g["NEG_prob"].mean()

        softmax_simple = {
            "positive": float(simple_pos) if not np.isnan(simple_pos) else None,
            "neutral":  float(simple_neu) if not np.isnan(simple_neu) else None,
            "negative": float(simple_neg) if not np.isnan(simple_neg) else None,
        }

        labels = (
            g["label_clean"]
            .dropna()
            .astype(str)
            .str.upper()
        )
        labels = labels[labels.isin(["POSITIVE", "NEUTRAL", "NEGATIVE"])]

        if labels.empty:
            vc = pd.Series(
                {"POSITIVE": 0, "NEUTRAL": 0, "NEGATIVE": 0}
            )
        else:
            vc = labels.value_counts()
            vc = vc.reindex(["POSITIVE", "NEUTRAL", "NEGATIVE"], fill_value=0)

        label_counts = vc.to_dict()
        majority_label = max(label_counts, key=label_counts.get)

        if pd.isna(weighted_score):
            score_implied_label = None
        elif weighted_score > 0.15:
            score_implied_label = "POSITIVE"
        elif weighted_score < -0.15:
            score_implied_label = "NEGATIVE"
        else:
            score_implied_label = "NEUTRAL"

        weighted_implied_label = _implied_from_dict(weighted_softmax)
        implied_label = _implied_from_dict(softmax_simple)

        if score_implied_label is None or majority_label is None:
            is_conflict = False
        else:
            is_conflict = (score_implied_label != majority_label)

        results.append({
            "date": get_group_date(g),
            "article_id": article_id,
            "ticker": ticker,

            "weighted_score": weighted_score,
            "majority_label": majority_label,           # snippet most votes
            "score_implied_label": score_implied_label, #  weighted_score 
            "weighted_implied_label": weighted_implied_label,  #  weighted_softmax
            "implied_label": implied_label,                    #  simple softmax
            "is_conflict": is_conflict,

            "POS_count": label_counts["POSITIVE"],
            "NEU_count": label_counts["NEUTRAL"],
            "NEG_count": label_counts["NEGATIVE"],
            "total_snippets": len(g),

            "weighted_softmax": weighted_softmax,
            "softmax": softmax_simple,
        })

    out = pd.DataFrame(results)
    return out

# %%
df['date'] = pd.to_datetime(df['date']).dt.date 
consistency_df = analyze_score_article(df)
consistency_df

# %%
def _softmax_to_series(d):
    if not isinstance(d, dict):
        return pd.Series({"pos_prob": np.nan, "neu_prob": np.nan, "neg_prob": np.nan})
    
    dd = {str(k).lower(): v for k, v in d.items()}
    return pd.Series({
        "pos_prob": dd.get("positive", np.nan),
        "neu_prob": dd.get("neutral",  np.nan),
        "neg_prob": dd.get("negative", np.nan),
    })

def _implied_from_probs(pos, neu, neg):
    if np.isnan(pos) or np.isnan(neu) or np.isnan(neg):
        return None
    
    scores = {
        "POSITIVE": pos,
        "NEUTRAL":  neu,
        "NEGATIVE": neg,
    }
    return max(scores, key=scores.get)

def aggregate_daily_ticker(df_article, softmax):
    df = df_article.copy()

    probs = df[softmax].apply(_softmax_to_series)
    df = pd.concat([df, probs], axis=1)

    grouped = df.groupby(["date", "ticker"], as_index=False).agg(
        pos_prob_mean=("pos_prob", "mean"),
        neu_prob_mean=("neu_prob", "mean"),
        neg_prob_mean=("neg_prob", "mean"),
        article_count=(softmax, "size")
    )

    def _make_daily_softmax(row):
        return {
            "positive": float(row["pos_prob_mean"]),
            "neutral":  float(row["neu_prob_mean"]),
            "negative": float(row["neg_prob_mean"]),
        }

    grouped["daily_softmax"] = grouped.apply(_make_daily_softmax, axis=1)

    grouped["classification"] = grouped.apply(
        lambda r: _implied_from_probs(
            r["pos_prob_mean"], r["neu_prob_mean"], r["neg_prob_mean"]
        ),
        axis=1
    )

    out = grouped[[
        "date",
        "ticker",
        "classification",
        "daily_softmax",
        "article_count",
    ]]

    return out

# %%
daily = aggregate_daily_ticker(consistency_df, 'softmax')
daily.rename(columns={"ticker": "entity"}, inplace=True)
daily.rename(columns={"daily_softmax": "softmax"}, inplace=True)

# %%
counts = daily["classification"].value_counts(dropna=False)
print("\nRaw counts:")
print(counts)

ordered = counts.reindex(["POSITIVE", "NEGATIVE", "NEUTRAL"])
print("\nOrdered counts (POS / NEG / NEU):")
print(ordered)
# Out:
# Raw counts:
# classification
# NEUTRAL     37242
# NEGATIVE     4429
# POSITIVE     2710
# Name: count, dtype: int64
#
# Ordered counts (POS / NEG / NEU):
# classification
# POSITIVE     2710
# NEGATIVE     4429
# NEUTRAL     37242
# Name: count, dtype: int64

# %%
daily.to_csv('../data/daily_absa_2022.csv')
